# %%
import pandas as pd

# %%
action_movies = pd.read_csv(r"C:\Users\aj824\Downloads\Ironhack Data Analytics 2024\Week 3 Project\week_3_project\imdb_movies_by_genre\action.csv")
action_movies

# %%
action_movies.rename(columns={'gross(in $)': 'gross'}, inplace=True)

# %%
action_movies.drop(columns=['star_id', 'director_id', 'description', 'star', 'gross'], inplace=True)

# %%
action_movies
# Out:
#          movie_id                         movie_name  year certificate  \
# 0       tt9114286     Black Panther: Wakanda Forever  2022       PG-13
# 1       tt1630029           Avatar: The Way of Water  2022       PG-13
# 2       tt5884796                              Plane  2023           R
# 3       tt6710474  Everything Everywhere All at Once  2022           R
# 4       tt5433140                             Fast X  2023         NaN
# ...           ...                                ...   ...         ...
# 52447  tt26743984                          Suicide 2  1999         NaN
# 52448  tt26744184                              Chaos  2023         NaN
# 52449  tt26744484                      Revolver Lily   NaN         NaN
# 52450  tt26744765                           The Wing   NaN         NaN
# 52451  tt26745202                       Vey Dharuvey   NaN         NaN
#
#        runtime                       genre  rating  \
# 0      161 min    Action, Adventure, Drama     6.9
# ...

# %%
action_movies.isna().sum()
# Out:
# movie_id           0
# movie_name         0
# year            8259
# certificate    38784
# runtime        19922
# genre              0
# rating         23004
# director        4633
# votes          23002
# dtype: int64

# %%
action_movies['rating'].fillna('N/A', inplace=True)

# %%
action_movies.rating.unique
# Out:
# <bound method Series.unique of 0        6.9
# 1        7.8
# 2        6.5
# 3        8.0
# 4        N/A
#         ...
# 52447    N/A
# 52448    N/A
# 52449    N/A
# 52450    N/A
# 52451    N/A
# Name: rating, Length: 52452, dtype: object>

# %%
action_movies = action_movies[action_movies['rating'] != 'N/A']

# %%
action_movies
# Out:
#          movie_id                         movie_name  year certificate  \
# 0       tt9114286     Black Panther: Wakanda Forever  2022       PG-13
# 1       tt1630029           Avatar: The Way of Water  2022       PG-13
# 2       tt5884796                              Plane  2023           R
# 3       tt6710474  Everything Everywhere All at Once  2022           R
# 5      tt10954600  Ant-Man and the Wasp: Quantumania  2023       PG-13
# ...           ...                                ...   ...         ...
# 52393   tt1786705                          The Hitch  2010         NaN
# 52404   tt1930512                    The Empty Hands  2011           R
# 52413   tt0270820                      Aag Ke Sholay  1988         NaN
# 52419   tt0432385                              AK 47  2004         NaN
# 52421   tt0465920                       Black & Blue  2001         NaN
#
#        runtime                       genre rating  \
# 0      161 min    Action, Adventure, Drama    6.9
# ...

# %%
action_movies['certificate'].fillna('N/A', inplace=True)

# %%
action_movies
# Out:
#          movie_id                         movie_name  year certificate  \
# 0       tt9114286     Black Panther: Wakanda Forever  2022       PG-13
# 1       tt1630029           Avatar: The Way of Water  2022       PG-13
# 2       tt5884796                              Plane  2023           R
# 3       tt6710474  Everything Everywhere All at Once  2022           R
# 5      tt10954600  Ant-Man and the Wasp: Quantumania  2023       PG-13
# ...           ...                                ...   ...         ...
# 52393   tt1786705                          The Hitch  2010         N/A
# 52404   tt1930512                    The Empty Hands  2011           R
# 52413   tt0270820                      Aag Ke Sholay  1988         N/A
# 52419   tt0432385                              AK 47  2004         N/A
# 52421   tt0465920                       Black & Blue  2001         N/A
#
#        runtime                       genre rating  \
# 0      161 min    Action, Adventure, Drama    6.9
# ...

# %%
print(action_movies['votes'].dtype)
# Out:
# float64

# %%
action_movies['votes'] = action_movies['votes'].astype(int)
action_movies['rating'] = action_movies['rating'].astype(float)

# %%
action_movies
# Out:
#          movie_id                         movie_name  year certificate  \
# 0       tt9114286     Black Panther: Wakanda Forever  2022       PG-13
# 1       tt1630029           Avatar: The Way of Water  2022       PG-13
# 2       tt5884796                              Plane  2023           R
# 3       tt6710474  Everything Everywhere All at Once  2022           R
# 5      tt10954600  Ant-Man and the Wasp: Quantumania  2023       PG-13
# ...           ...                                ...   ...         ...
# 52393   tt1786705                          The Hitch  2010         N/A
# 52404   tt1930512                    The Empty Hands  2011           R
# 52413   tt0270820                      Aag Ke Sholay  1988         N/A
# 52419   tt0432385                              AK 47  2004         N/A
# 52421   tt0465920                       Black & Blue  2001         N/A
#
#        runtime                       genre  rating  \
# 0      161 min    Action, Adventure, Drama     6.9
# ...

# %%
# Suponiendo que action_movies es tu DataFrame y las columnas se llaman 'votes', 'movie_name' y 'rating'
top_movies = action_movies[['movie_name', 'votes', 'rating']].sort_values(by='votes', ascending=False).head(10)
print(top_movies)
# Out:
#                                             movie_name    votes  rating
# 33                                     The Dark Knight  2675531     9.0
# 34                                           Inception  2373682     8.8
# 52                                          The Matrix  1928021     8.7
# 28   The Lord of the Rings: The Fellowship of the Ring  1889727     8.8
# 74       The Lord of the Rings: The Return of the King  1860374     9.0
# 115                              The Dark Knight Rises  1717874     8.4
# 111              The Lord of the Rings: The Two Towers  1679818     8.8
# 38                                           Gladiator  1512747     8.5
# 164                                      Batman Begins  1482505     8.2
# 184                                       The Avengers  1400257     8.0

# %%
# Ordenamos las películas por la cantidad de votos en orden descendente
sorted_movies = action_movies.sort_values(by='votes', ascending=False)

# Seleccionamos la película con la mayor calificación de entre las primeras
top_rated_movie = sorted_movies.iloc[0]

# Mostramos la película con la mayor calificación entre las más votadas
print("Película con más votos y mayor rating:")
print("Nombre:", top_rated_movie['movie_name'])
print("Votos:", top_rated_movie['votes'])
print("Rating:", top_rated_movie['rating'])
# Out:
# Película con más votos y mayor rating:
# Nombre: The Dark Knight
# Votos: 2675531
# Rating: 9.0

# %%
# Ordenamos las películas por la cantidad de votos en orden descendente
sorted_movies = action_movies.sort_values(by='votes', ascending=False)
sorted_movies.reset_index(drop = True, inplace = True)
sorted_movies.index += 1
# Seleccionamos las 10 películas con más votos
top_10_movies = sorted_movies.head(10)

# De las 10 películas seleccionadas, encontramos aquella con el mayor rating
top_rated_movie = top_10_movies.loc[top_10_movies['rating'].idxmax()]

# Mostramos las 10 películas con más votos y la película con el mayor rating entre ellas
print("Las 10 películas con más votos:")
print(top_10_movies[['movie_name', 'votes', 'rating']])
print("\nPelícula con más votos y mayor rating:")
print("Nombre:", top_rated_movie['movie_name'])
print("Votos:", top_rated_movie['votes'])
print("Rating:", top_rated_movie['rating'])
# Out:
# Las 10 películas con más votos:
#                                            movie_name    votes  rating
# 1                                     The Dark Knight  2675531     9.0
# 2                                           Inception  2373682     8.8
# 3                                          The Matrix  1928021     8.7
# 4   The Lord of the Rings: The Fellowship of the Ring  1889727     8.8
# 5       The Lord of the Rings: The Return of the King  1860374     9.0
# 6                               The Dark Knight Rises  1717874     8.4
# 7               The Lord of the Rings: The Two Towers  1679818     8.8
# 8                                           Gladiator  1512747     8.5
# 9                                       Batman Begins  1482505     8.2
# 10                                       The Avengers  1400257     8.0
#
# Película con más votos y mayor rating:
# Nombre: The Dark Knight
# Votos: 2675531
# Rating: 9.0

# %%
top_10_movies
# Out:
#       movie_id                                         movie_name  year  \
# 33   tt0468569                                    The Dark Knight  2008
# 34   tt1375666                                          Inception  2010
# 52   tt0133093                                         The Matrix  1999
# 28   tt0120737  The Lord of the Rings: The Fellowship of the Ring  2001
# 74   tt0167260      The Lord of the Rings: The Return of the King  2003
# 115  tt1345836                              The Dark Knight Rises  2012
# 111  tt0167261              The Lord of the Rings: The Two Towers  2002
# 38   tt0172495                                          Gladiator  2000
# 164  tt0372784                                      Batman Begins  2005
# 184  tt0848228                                       The Avengers  2012
#
#     certificate  runtime                      genre  rating  \
# 33        PG-13  152 min       Action, Crime, Drama     9.0
# ...

# %%
# Ordenamos las películas por la cantidad de votos en orden descendente
sorted_movies = action_movies.sort_values(by='votes', ascending=False)

# Seleccionamos las 10 películas con más votos
top_10_movies = sorted_movies.head(10)

# De las 10 películas seleccionadas, encontramos aquella con el mayor rating
top_rated_movie = top_10_movies.loc[top_10_movies['rating'].idxmax()]

# Mostramos las 10 películas con más votos y la película con el mayor rating entre ellas
print("Las 10 películas con más votos:")
print(top_10_movies[['movie_name', 'director', 'votes', 'rating']])
print("\nPelícula con más votos y mayor rating:")
print("Nombre:", top_rated_movie['movie_name'])
print("Director:", top_rated_movie['director'])
print("Votos:", top_rated_movie['votes'])
print("Rating:", top_rated_movie['rating'])
# Out:
# Las 10 películas con más votos:
#                                             movie_name  \
# 33                                     The Dark Knight
# 34                                           Inception
# 52                                          The Matrix
# 28   The Lord of the Rings: The Fellowship of the Ring
# 74       The Lord of the Rings: The Return of the King
# 115                              The Dark Knight Rises
# 111              The Lord of the Rings: The Two Towers
# 38                                           Gladiator
# 164                                      Batman Begins
# 184                                       The Avengers
#
#                                 director    votes  rating
# 33                     Christopher Nolan  2675531     9.0
# 34                     Christopher Nolan  2373682     8.8
# 52   Lana Wachowski, \r\nLilly Wachowski  1928021     8.7
# 28                         Peter Jackson  1889727     8.8
# ...

# %% [markdown]
# # Alejandro Figueroa Dev Space

# %%
import requests
import pandas as pd

url = "https://moviesdatabase.p.rapidapi.com/titles/{id}"
querystring = {"info":"revenue_budget"}

headers = {
	"x-rapidapi-key": "9292e06bc9msh8780a7a7cba2601p11bfb1jsn413dded59c5d",
	"x-rapidapi-host": "moviesdatabase.p.rapidapi.com",
	"Content-Type": "application/json"
}

# Function to format a value as currency
def format_currency(value):
    return "${:,.2f}".format(value)

# Function to send movie_id to API
def send_movie_id(movie_id):
    response = requests.get(url.format(id=movie_id), headers=headers, params=querystring)
    
    if response.status_code == 200:
        return response.json()
    else:
        print("Could not get response from API")
    
    

# Iterate over DataFrame and send each movie_id
def get_worldwide_gross_movie(movie_df):
    
    # This list will store the values for gross of each movie
    gross_list = []
    try: 
        for movie_id in movie_df['movie_id']:
            response = send_movie_id(movie_id)
            gross_list.append(format_currency(response['results']['worldwideGross']['total']['amount']))
        
        movie_df['worldwide_gross'] = gross_list
    except Exception as e:
        print(f"Could not get response from API: {e}")

# %%
def get_top_10_movies(csv_path):
    try:
        # Create dataframe from CSV file
        movie_df = pd.read_csv(csv_path)
        
        # Drop unnecessary columns
        movie_df.drop(columns=['star_id', 'director_id', 'description', 'star', 'gross(in $)'], inplace=True)
        
        # Fill null values in columns we will use for analysis
        movie_df['rating'].fillna('N/A', inplace=True)
        movie_df['certificate'].fillna('N/A', inplace=True)
        
        # Cleanup in the director column
        movie_df['director'].apply(lambda name: str(name).replace("\r\n","&"))
        
        # Filtering for movies that have a rating
        movie_df = movie_df[movie_df['rating'] != 'N/A']
        
        # Changing data type for columns
        movie_df['votes'] = movie_df['votes'].astype(int)
        movie_df['rating'] = movie_df['rating'].astype(float)
        
        # Sort movies in descending order by votes and rating
        movie_df.sort_values(by=['votes', 'rating'], ascending=[False, False], inplace=True)
        
        # Reset index to 0 and start at 1
        movie_df.reset_index(drop = True, inplace = True)
        movie_df.index += 1
        
        top_movies = movie_df.head(10)
        
        return top_movies    
        
    except Exception as e:
        print(f"Error getting your top 10 movies: {e}")

# %% [markdown]
# ## Top 10 Action Movies

# %%
top_10_action_movies = get_top_10_movies(r"C:\Users\aj824\Downloads\Ironhack Data Analytics 2024\Week 3 Project\week_3_project\imdb_movies_by_genre\action.csv")

get_worldwide_gross_movie(top_10_action_movies)
top_10_action_movies
# Out:
#      movie_id                                         movie_name  year  \
# 1   tt0468569                                    The Dark Knight  2008
# 2   tt1375666                                          Inception  2010
# 3   tt0133093                                         The Matrix  1999
# 4   tt0120737  The Lord of the Rings: The Fellowship of the Ring  2001
# 5   tt0167260      The Lord of the Rings: The Return of the King  2003
# 6   tt1345836                              The Dark Knight Rises  2012
# 7   tt0167261              The Lord of the Rings: The Two Towers  2002
# 8   tt0172495                                          Gladiator  2000
# 9   tt0372784                                      Batman Begins  2005
# 10  tt0848228                                       The Avengers  2012
#
#    certificate  runtime                      genre  rating  \
# 1        PG-13  152 min       Action, Crime, Drama     9.0
# 2        PG-13  148 min  Action, Adventure, Sci-Fi     8.8
# ...

# %% [markdown]
# ## Top 10 Animated Movies

# %%
top_10_animated_movies = get_top_10_movies(r"C:\Users\aj824\Downloads\Ironhack Data Analytics 2024\Week 3 Project\week_3_project\imdb_movies_by_genre\animation.csv")

get_worldwide_gross_movie(top_10_animated_movies)
top_10_animated_movies
# Out:
#      movie_id                movie_name  year certificate  runtime  \
# 1   tt0910970                    WALL·E  2008           G   98 min
# 2   tt0110357             The Lion King  1994           G   88 min
# 3   tt1049413                        Up  2009          PG   96 min
# 4   tt0266543              Finding Nemo  2003           G  100 min
# 5   tt0114709                 Toy Story  1995           G   81 min
# 6   tt0198781            Monsters, Inc.  2001           G   92 min
# 7   tt0435761               Toy Story 3  2010           G  103 min
# 8   tt0245429             Spirited Away  2001          PG  125 min
# 9   tt0382932               Ratatouille  2007           G  111 min
# 10  tt0892769  How to Train Your Dragon  2010          PG   98 min
#
#                            genre  rating  \
# 1   Animation, Adventure, Family     8.4
# 2    Animation, Adventure, Drama     8.5
# 3   Animation, Adventure, Comedy     8.3
# 4   Animation, Adventure, Comedy     8.2
# ...

# %% [markdown]
# ## Top 10 Horror Movies

# %%
top_10_horror_movies = get_top_10_movies(r"C:\Users\aj824\Downloads\Ironhack Data Analytics 2024\Week 3 Project\week_3_project\imdb_movies_by_genre\horror.csv")

get_worldwide_gross_movie(top_10_horror_movies)
top_10_horror_movies
# Out:
#      movie_id         movie_name  year certificate  runtime  \
# 1   tt0081505        The Shining  1980           R  146 min
# 2   tt0078748              Alien  1979           R  117 min
# 3   tt0480249        I Am Legend  2007       PG-13  101 min
# 4   tt0054215             Psycho  1960           R  109 min
# 5   tt0816711        World War Z  2013       PG-13  116 min
# 6   tt0144084    American Psycho  2000           R  102 min
# 7   tt5052448            Get Out  2017           R  104 min
# 8   tt1156398         Zombieland  2009           R   88 min
# 9   tt0365748  Shaun of the Dead  2004           R   99 min
# 10  tt1396484                 It  2017           R  135 min
#
#                         genre  rating          director    votes  \
# 1               Drama, Horror     8.4   Stanley Kubrick  1032203
# 2              Horror, Sci-Fi     8.5      Ridley Scott   890417
# 3       Action, Drama, Horror     7.2  Francis Lawrence   768223
# ...

# %% [markdown]
# ## Top 10 Thriller Movies

# %%
top_10_thriller_movies = get_top_10_movies(r"C:\Users\aj824\Downloads\Ironhack Data Analytics 2024\Week 3 Project\week_3_project\imdb_movies_by_genre\thriller.csv")

get_worldwide_gross_movie(top_10_thriller_movies)
top_10_thriller_movies
# Out:
#      movie_id                movie_name  year certificate  runtime  \
# 1   tt0468569           The Dark Knight  2008       PG-13  152 min
# 2   tt1375666                 Inception  2010       PG-13  148 min
# 3   tt0114369                     Se7en  1995           R  127 min
# 4   tt0102926  The Silence of the Lambs  1991           R  118 min
# 5   tt0482571              The Prestige  2006       PG-13  130 min
# 6   tt0407887              The Departed  2006           R  151 min
# 7   tt1130884            Shutter Island  2010           R  138 min
# 8   tt7286456                     Joker  2019           R  122 min
# 9   tt0209144                   Memento  2000           R  113 min
# 10  tt0110413    Léon: The Professional  1994           R  110 min
#
#                         genre  rating           director    votes  \
# 1        Action, Crime, Drama     9.0  Christopher Nolan  2675531
# 2   Action, Adventure, Sci-Fi     8.8  Christopher Nolan  2373682
# ...

# %% [markdown]
# ## Top 10 Thriller Movies

# %%
top_10_fantasy_movies = get_top_10_movies(r"C:\Users\aj824\Downloads\Ironhack Data Analytics 2024\Week 3 Project\week_3_project\imdb_movies_by_genre\fantasy.csv")

get_worldwide_gross_movie(top_10_fantasy_movies)
top_10_fantasy_movies
# Out:
#      movie_id                                         movie_name  year  \
# 1   tt0120737  The Lord of the Rings: The Fellowship of the Ring  2001
# 2   tt0167260      The Lord of the Rings: The Return of the King  2003
# 3   tt0167261              The Lord of the Rings: The Two Towers  2002
# 4   tt0076759                                          Star Wars  1977
# 5   tt0499549                                             Avatar  2009
# 6   tt0120689                                     The Green Mile  1999
# 7   tt0080684     Star Wars: Episode V - The Empire Strikes Back  1980
# 8   tt0325980  Pirates of the Caribbean: The Curse of the Bla...  2003
# 9   tt0086190         Star Wars: Episode VI - Return of the Jedi  1983
# 10  tt0114709                                          Toy Story  1995
#
#    certificate  runtime                         genre  rating  \
# 1        PG-13  178 min      Action, Adventure, Drama     8.8
# ...

# %% [markdown]
# ## Top 10 Film Noir Movies

# %%
top_10_filmnoir_movies = get_top_10_movies(r"C:\Users\aj824\Downloads\Ironhack Data Analytics 2024\Week 3 Project\week_3_project\imdb_movies_by_genre\film-noir.csv")

get_worldwide_gross_movie(top_10_filmnoir_movies)
top_10_filmnoir_movies
# Out:
#      movie_id               movie_name  year certificate  runtime  \
# 1   tt0043014             Sunset Blvd.  1950         N/A  110 min
# 2   tt0041959            The Third Man  1949           U  104 min
# 3   tt0033870       The Maltese Falcon  1941         N/A  100 min
# 4   tt0036775         Double Indemnity  1944         N/A  107 min
# 5   tt0032976                  Rebecca  1940         N/A  130 min
# 6   tt0044079     Strangers on a Train  1951           A  101 min
# 7   tt0052311            Touch of Evil  1958       PG-13   95 min
# 8   tt0038787                Notorious  1946           U  102 min
# 9   tt0049406              The Killing  1956         N/A   84 min
# 10  tt0048424  The Night of the Hunter  1955           A   92 min
#
#                            genre  rating          director   votes  \
# 1               Drama, Film-Noir     8.4      Billy Wilder  224111
# 2   Film-Noir, Mystery, Thriller     8.1        Carol Reed  173375
# ...
